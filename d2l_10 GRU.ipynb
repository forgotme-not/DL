# %% [markdown]
# GRU门控单元
# ![image.png](attachment:e4931937-d397-4a93-ac1e-710210bae96c.png)
# 通过一些控制单元来实现对隐藏状态的选择
# ![image.png](attachment:de6112c5-73d8-45bd-8a1c-1487fba96de4.png)
# 门是一个长度跟隐藏状态一样的向量
# ![image.png](attachment:0c893710-5d60-451e-8492-1d0d4adaf08a.png)
# 哈达玛积:矩阵对应的位置做乘法，得到新的矩阵
#
# 当Rt全为0时，则全部置0，丢掉前面的所有隐藏状态，Rt全为1时，则保留全部状态
# ![image.png](attachment:426669eb-530f-4135-a3bc-9e99a99b30c2.png)
# 更新门：当Z全为1时则不更新隐藏状态，当Z全为0时，则完全按照候选隐藏状态来更新隐藏状态
# ![image.png](attachment:90b5a44e-02bb-4fbd-822c-ecb2a967e56a.png)
